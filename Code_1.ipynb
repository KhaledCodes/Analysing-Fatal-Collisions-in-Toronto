# %%
import pandas as pd
import json
import requests
import matplotlib.pyplot as plt

# %%
filepath = "Resources/Fatal_Collisions.csv"
fatal_coll=pd.read_csv(filepath)
fatal_coll.head()
# Out:
#            X          Y    Index_      ACCNUM  YEAR                      DATE  \
# 0 -79.227590  43.816245   7377669     1275814  2012  2012-01-12T05:00:00.000Z
# 1 -79.447742  43.637614  80000014   131058335  2013  2013-11-29T05:00:00.000Z
# 2 -79.259883  43.716773  80944448  8001077165  2018  2018-06-14T04:00:00.000Z
# 3 -79.316890  43.821345   6253540     1162012  2010  2010-04-13T04:00:00.000Z
# 4 -79.574641  43.728129  80501551  4003267619  2014  2014-11-09T05:00:00.000Z
#
#    TIME  Hour                 STREET1          STREET2  ... EMERG_VEH  \
# 0   558     5              NEILSON RD      FINCH AVE E  ...
# 1   558     5  1491 LAKE SHORE BLVD W                   ...
# 2   558     5          ST CLAIR AVE E      DANFORTH RD  ...
# 3   559     5           STEELES AVE E    BIRCHMOUNT RD  ...
# 4   559     5             KIPLING AVE  WESTHUMBER BLVD  ...
#
#   PASSENGER SPEEDING  AG_DRIV  REDLIGHT  ALCOHOL  DISABILITY  Hood_ID  \
# 0       Yes               Yes                                     132
# 1                Yes      Yes                                      85
# 2                         Yes                                     120
# 3       Yes               Yes       Yes                  Yes      116
# 4       Yes               Yes       Yes                             4
#
#                   Neighbourh  ObjectId
# 0              Malvern (132)         1
# 1        South Parkdale (85)         2
# 2  Clairlea-Birchmount (120)         3
# 3              Steeles (116)         4
# 4        Rexdale-Kipling (4)         5
#
# [5 rows x 60 columns]

# %%
fatal_col1=fatal_coll[['LATITUDE','LONGITUDE','STREET1','STREET2','DATE','TIME','YEAR','ROAD_CLASS','District','LOCCOORD','TRAFFCTL','VISIBILITY','LIGHT',
                       'INVTYPE','INVAGE','VEHTYPE','MANOEUVER','DRIVACT','DRIVCOND','PEDESTRIAN','CYCLIST','AUTOMOBILE','MOTORCYCLE','TRUCK','SPEEDING','REDLIGHT','ALCOHOL','Neighbourh','ObjectId']]

# %%
fatal_col1.columns
# Out:
# Index(['LATITUDE', 'LONGITUDE', 'STREET1', 'STREET2', 'DATE', 'TIME', 'YEAR',
#        'ROAD_CLASS', 'District', 'LOCCOORD', 'TRAFFCTL', 'VISIBILITY', 'LIGHT',
#        'INVTYPE', 'INVAGE', 'VEHTYPE', 'MANOEUVER', 'DRIVACT', 'DRIVCOND',
#        'PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE', 'MOTORCYCLE', 'TRUCK',
#        'SPEEDING', 'REDLIGHT', 'ALCOHOL', 'Neighbourh', 'ObjectId'],
#       dtype='object')

# %%
fatal_col2=fatal_col1.rename(columns={"LOCCOORD":"INTERSECTION","ROAD_CLASS":"ACCIDENT LANE","INVTYPE":"VICTIM","INVAGE":"VICTIM AGE"})
fatal_col2.columns
# Out:
# Index(['LATITUDE', 'LONGITUDE', 'STREET1', 'STREET2', 'DATE', 'TIME', 'YEAR',
#        'ACCIDENT LANE', 'District', 'INTERSECTION', 'TRAFFCTL', 'VISIBILITY',
#        'LIGHT', 'VICTIM', 'VICTIM AGE', 'VEHTYPE', 'MANOEUVER', 'DRIVACT',
#        'DRIVCOND', 'PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE', 'MOTORCYCLE',
#        'TRUCK', 'SPEEDING', 'REDLIGHT', 'ALCOHOL', 'Neighbourh', 'ObjectId'],
#       dtype='object')

# %%
fatal_col3=fatal_col2[['LATITUDE','LONGITUDE','DATE','TIME','YEAR','ACCIDENT LANE','District','INTERSECTION','VISIBILITY','LIGHT',
                       'VICTIM','VICTIM AGE','VEHTYPE','DRIVACT','PEDESTRIAN','CYCLIST','AUTOMOBILE','MOTORCYCLE','TRUCK','SPEEDING','REDLIGHT','ALCOHOL','Neighbourh','ObjectId']]

# %%
fatal_col4=fatal_col3
fatal_col4.columns
# Out:
# Index(['LATITUDE', 'LONGITUDE', 'DATE', 'TIME', 'YEAR', 'ACCIDENT LANE',
#        'District', 'INTERSECTION', 'VISIBILITY', 'LIGHT', 'VICTIM',
#        'VICTIM AGE', 'VEHTYPE', 'DRIVACT', 'PEDESTRIAN', 'CYCLIST',
#        'AUTOMOBILE', 'MOTORCYCLE', 'TRUCK', 'SPEEDING', 'REDLIGHT', 'ALCOHOL',
#        'Neighbourh', 'ObjectId'],
#       dtype='object')

# %%
def cause_finder(r):
    
    if ((r['ALCOHOL'] == 'Yes') and (r['ALCOHOL'] == 'Yes')):
        v = "Alcohol & Speeding"
    elif (r['SPEEDING'] == 'Yes'):
        v = "Speeding"
    elif (r['ALCOHOL'] == 'Yes'):
        v = "Alcohol"
    elif ((r['DRIVACT']!='Driving Properly') and (r['DRIVACT']!='Other') and (r['DRIVACT']!='') and (r['DRIVACT']!=' ')):
        v= r['DRIVACT']
    elif ((r['VISIBILITY']!='Clear')):
        v= r['VISIBILITY']
    elif ((r['LIGHT']!='Daylight') and (r['LIGHT']!='Daylight, artificial')):
        v= 'Low Light Conditions'
    else:
        v='Unknown'
 
    return v

fatal_col4['Cause'] = fatal_col4.apply(cause_finder, axis = 1)
#fatal_col4.loc[fatal_col4['Cause_Real']=='']
fatal_col4['Cause'].value_counts()
# Out:
# C:\Users\ARJUNJohri\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Unknown                         202
# Low Light Conditions            132
# Speeding                        126
# Rain                             51
# Alcohol & Speeding               30
# Lost control                     30
# Other                            12
# Disobeyed Traffic Control         8
# Snow                              6
#                                   4
# Failed to Yield Right of Way      3
# Improper Turn                     2
# Improper Lane Change              1
# Freezing Rain                     1
# Following too Close               1
# Speed too Slow                    1
# Name: Cause, dtype: int64

# %%
fatal_col4.head()
# Out:
#     LATITUDE  LONGITUDE                      DATE  TIME  YEAR   ACCIDENT LANE  \
# 0  43.816245 -79.227590  2012-01-12T05:00:00.000Z   558  2012  Minor Arterial
# 1  43.637614 -79.447742  2013-11-29T05:00:00.000Z   558  2013  Major Arterial
# 2  43.716773 -79.259883  2018-06-14T04:00:00.000Z   558  2018  Major Arterial
# 3  43.821345 -79.316890  2010-04-13T04:00:00.000Z   559  2010  Major Arterial
# 4  43.728129 -79.574641  2014-11-09T05:00:00.000Z   559  2014  Major Arterial
#
#                 District  INTERSECTION VISIBILITY             LIGHT  ...  \
# 0            Scarborough  Intersection       Rain  Dark, artificial  ...
# 1  Toronto and East York     Mid-Block      Clear  Dawn, artificial  ...
# 2            Scarborough  Intersection      Clear          Daylight  ...
# 3            Scarborough  Intersection      Clear              Dawn  ...
# 4         Etobicoke York  Intersection      Clear  Dark, artificial  ...
#
#   AUTOMOBILE MOTORCYCLE TRUCK SPEEDING REDLIGHT ALCOHOL  \
# 0        Yes
# 1        Yes                       Yes
# 2        Yes        Yes
# 3        Yes                                Yes
# 4        Yes                                Yes
#
#                   Neighbourh ObjectId Cause_Real                 Cause
# 0              Malvern (132)        1       Rain                  Rain
# 1        South Parkdale (85)        2   Speeding              Speeding
# 2  Clairlea-Birchmount (120)        3    Unknown               Unknown
# 3              Steeles (116)        4    Unknown  Low Light Conditions
# 4        Rexdale-Kipling (4)        5    Unknown  Low Light Conditions
#
# [5 rows x 26 columns]

# %%
Accident_info=fatal_col4[['LATITUDE', 'LONGITUDE', 'DATE', 'TIME', 'YEAR', 'ACCIDENT LANE','District', 'INTERSECTION',
                          'VICTIM','VICTIM AGE', 'VEHTYPE', 'PEDESTRIAN', 'CYCLIST','AUTOMOBILE', 'MOTORCYCLE', 
                          'TRUCK', 'Cause','Neighbourh']]
Accident_info.to_csv("Accident_info.csv")
fatal_col4.to_csv("Fatal Collisions.csv")
Accident_info.head()
# Out:
#     LATITUDE  LONGITUDE                      DATE  TIME  YEAR   ACCIDENT LANE  \
# 0  43.816245 -79.227590  2012-01-12T05:00:00.000Z   558  2012  Minor Arterial
# 1  43.637614 -79.447742  2013-11-29T05:00:00.000Z   558  2013  Major Arterial
# 2  43.716773 -79.259883  2018-06-14T04:00:00.000Z   558  2018  Major Arterial
# 3  43.821345 -79.316890  2010-04-13T04:00:00.000Z   559  2010  Major Arterial
# 4  43.728129 -79.574641  2014-11-09T05:00:00.000Z   559  2014  Major Arterial
#
#                 District  INTERSECTION             VICTIM VICTIM AGE  \
# 0            Scarborough  Intersection         Pedestrian   40 to 44
# 1  Toronto and East York     Mid-Block             Driver   25 to 29
# 2            Scarborough  Intersection  Motorcycle Driver   55 to 59
# 3            Scarborough  Intersection          Passenger   70 to 74
# 4         Etobicoke York  Intersection          Passenger   20 to 24
#
#                      VEHTYPE PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE TRUCK  \
# 0                      Other        Yes                Yes
# 1  Automobile, Station Wagon                           Yes
# 2                 Motorcycle                           Yes        Yes
# 3                      Other                           Yes
# 4                                                      Yes
#
#                   Cause                 Neighbourh
# 0                  Rain              Malvern (132)
# 1              Speeding        South Parkdale (85)
# 2               Unknown  Clairlea-Birchmount (120)
# 3  Low Light Conditions              Steeles (116)
# 4  Low Light Conditions        Rexdale-Kipling (4)
