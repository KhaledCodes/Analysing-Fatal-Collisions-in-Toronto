# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
from pprint import pprint
from config import gkey
import gmaps.datasets
import gmaps
import time

# %%
TPS_df = pd.read_csv("Accident_info.csv")
TPS_df.head()
# Out:
#    Unnamed: 0   LATITUDE  LONGITUDE                      DATE  TIME  YEAR  \
# 0           0  43.816245 -79.227590  2012-01-12T05:00:00.000Z   558  2012
# 1           1  43.637614 -79.447742  2013-11-29T05:00:00.000Z   558  2013
# 2           2  43.716773 -79.259883  2018-06-14T04:00:00.000Z   558  2018
# 3           3  43.821345 -79.316890  2010-04-13T04:00:00.000Z   559  2010
# 4           4  43.728129 -79.574641  2014-11-09T05:00:00.000Z   559  2014
#
#     ACCIDENT LANE               District  INTERSECTION             VICTIM  \
# 0  Minor Arterial            Scarborough  Intersection         Pedestrian
# 1  Major Arterial  Toronto and East York     Mid-Block             Driver
# 2  Major Arterial            Scarborough  Intersection  Motorcycle Driver
# 3  Major Arterial            Scarborough  Intersection          Passenger
# 4  Major Arterial         Etobicoke York  Intersection          Passenger
#
#   VICTIM AGE                    VEHTYPE           DRIVACT PEDESTRIAN CYCLIST  \
# 0   40 to 44                      Other                          Yes
# 1   25 to 29  Automobile, Station Wagon      Lost control
# 2   55 to 59                 Motorcycle  Driving Properly
# 3   70 to 74                      Other
# 4   20 to 24
#
#   AUTOMOBILE MOTORCYCLE TRUCK     Cause                 Neighbourh
# 0        Yes                                         Malvern (132)
# 1        Yes                   Speeding        South Parkdale (85)
# 2        Yes        Yes         Unknown  Clairlea-Birchmount (120)
# 3        Yes                                         Steeles (116)
# 4        Yes                                   Rexdale-Kipling (4)

# %%
lats=[]
lngs=[]
for index,row in TPS_df.iterrows():
    lats.append(row[1])
    lngs.append(row[2])

# %%
popinc=pd.read_csv('Population Income Neighborhood.csv')
popinc.head()
# Out:
#    Unnamed: 0                      Category Population  \
# 0           0               Agincourt North     29,113
# 1           1  Agincourt South-Malvern West     23,757
# 2           2                     Alderwood     12,054
# 3           3                         Annex     30,526
# 4           4             Banbury-Don Mills     27,695
#
#    Neighborhood Mean Income        Lat       Long
# 0               52532.74050  43.808053 -79.266502
# 1               50550.17153  43.788009 -79.283882
# 2               55229.36660  43.601710 -79.545238
# 3               45009.96767  43.669833 -79.407585
# 4               52962.59704  43.749115 -79.366359

# %%
# enable jupyter extensions
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# install gmaps
# !pip install gmaps
# enable gmaps
# !jupyter nbextension enable --py --sys-prefix gmaps
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok
# Requirement already satisfied: gmaps in c:\users\arjunjohri\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: six in c:\users\arjunjohri\anaconda3\lib\site-packages (from gmaps) (1.12.0)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\arjunjohri\anaconda3\lib\site-packages (from gmaps) (4.3.2)
# Requirement already satisfied: geojson>=2.0.0 in c:\users\arjunjohri\anaconda3\lib\site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\arjunjohri\anaconda3\lib\site-packages (from gmaps) (7.4.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\arjunjohri\anaconda3\lib\site-packages (from gmaps) (7.4.2)
# Requirement already satisfied: decorator in c:\users\arjunjohri\anaconda3\lib\site-packages (from traitlets>=4.3.0->gmaps) (4.4.0)
# Requirement already satisfied: ipython-genutils in c:\users\arjunjohri\anaconda3\lib\site-packages (from traitlets>=4.3.0->gmaps) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\arjunjohri\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\arjunjohri\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.1)
# Requirement already satisfied: pygments in c:\users\arjunjohri\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (2.3.1)
# Requirement already satisfied: backcall in c:\users\arjunjohri\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.1.0)
# Requirement already satisfied: jedi>=0.10 in c:\users\arjunjohri\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.13.3)
# Requirement already satisfied: setuptools>=18.5 in c:\users\arjunjohri\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (40.8.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in c:\users\arjunjohri\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (2.0.9)
# Requirement already satisfied: widgetsnbextension~=3.4.0 in c:\users\arjunjohri\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.4.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\arjunjohri\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (4.4.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\arjunjohri\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.0)
# Requirement already satisfied: parso>=0.3.0 in c:\users\arjunjohri\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.3.4)
# Requirement already satisfied: wcwidth in c:\users\arjunjohri\anaconda3\lib\site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.1.7)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\arjunjohri\anaconda3\lib\site-packages (from widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->gmaps) (5.7.8)
# Requirement already satisfied: jupyter-core in c:\users\arjunjohri\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.4.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\arjunjohri\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.0.1)
# Requirement already satisfied: jupyter-client in c:\users\arjunjohri\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (5.2.4)
# Requirement already satisfied: tornado>=4.2 in c:\users\arjunjohri\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.0.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\arjunjohri\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->gmaps) (18.0.0)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\arjunjohri\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->gmaps) (0.8.1)
# Requirement already satisfied: Send2Trash in c:\users\arjunjohri\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: jinja2 in c:\users\arjunjohri\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->gmaps) (2.10)
# Requirement already satisfied: nbconvert in c:\users\arjunjohri\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->gmaps) (5.4.1)
# Requirement already satisfied: prometheus-client in c:\users\arjunjohri\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\arjunjohri\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (19.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\arjunjohri\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.14.11)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\arjunjohri\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\arjunjohri\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: mistune>=0.8.1 in c:\users\arjunjohri\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\arjunjohri\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: bleach in c:\users\arjunjohri\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->gmaps) (3.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\arjunjohri\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->gmaps) (1.4.2)
# Requirement already satisfied: testpath in c:\users\arjunjohri\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->gmaps) (0.4.2)
# Requirement already satisfied: defusedxml in c:\users\arjunjohri\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->gmaps) (0.5.0)
# Requirement already satisfied: webencodings in c:\users\arjunjohri\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: ok

# %%
gmaps.configure(api_key=gkey)

# %%
a=[]
for z in range(0,len(popinc['Neighborhood Mean Income'])):
    a.append((popinc.iloc[z,3]/10000).astype(int))
    
x=(np.array(a)*2).astype(int)
len(x)
b=x.tolist()

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(TPS_df[["LATITUDE","LONGITUDE"]],max_intensity=1)

fig.add_layer(heat_layer)

marker_layer = gmaps.symbol_layer(popinc[["Lat","Long"]],stroke_opacity=0.4,fill_opacity=0.6,scale=b)# scale is income parameter
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
from math import sin, cos, sqrt, atan2, radians
def calculate_distance(lat1, lon1, lat2, lon2):
   R = 6373.0
   lat1 = radians(lat1)
   lon1 = radians(lon1)
   lat2 = radians(lat2)
   lon2 = radians(lon2)
   dlon = lon2 - lon1
   dlat = lat2 - lat1
   a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
   c = 2 * atan2(sqrt(a), sqrt(1 - a))
   return R * c
print(calculate_distance(52.2296756,21.0122287,52.406374,16.9251681))
# Out:
# 278.54558935106695

# %%
popinc["Number of Accidents"]=0
# Out:
#    Unnamed: 0                      Category Population  \
# 0           0               Agincourt North     29,113
# 1           1  Agincourt South-Malvern West     23,757
# 2           2                     Alderwood     12,054
# 3           3                         Annex     30,526
# 4           4             Banbury-Don Mills     27,695
#
#    Neighborhood Mean Income        Lat       Long  Number of Accidents
# 0               52532.74050  43.808053 -79.266502                    0
# 1               50550.17153  43.788009 -79.283882                    0
# 2               55229.36660  43.601710 -79.545238                    0
# 3               45009.96767  43.669833 -79.407585                    0
# 4               52962.59704  43.749115 -79.366359                    0

# %%
for w in range(len(TPS_df)):
    mini=100000
    for y in range(len(popinc)):
           
        dist = calculate_distance(TPS_df.iloc[w,1],TPS_df.iloc[w,2],popinc.iloc[y,4],popinc.iloc[y,5])
        if (dist<mini):
            mini=dist
            y1=y
    popinc.iloc[y1,6]=popinco.iloc[y1,6]+1
popinc.head()
# Out:
#    Unnamed: 0                      Category Population  \
# 0           0               Agincourt North     29,113
# 1           1  Agincourt South-Malvern West     23,757
# 2           2                     Alderwood     12,054
# 3           3                         Annex     30,526
# 4           4             Banbury-Don Mills     27,695
#
#    Neighborhood Mean Income        Lat       Long  Number of Accidents
# 0               52532.74050  43.808053 -79.266502                    8
# 1               50550.17153  43.788009 -79.283882                    5
# 2               55229.36660  43.601710 -79.545238                    1
# 3               45009.96767  43.669833 -79.407585                    1
# 4               52962.59704  43.749115 -79.366359                    1

# %%
popinc=popinc.drop(axis='columns',columns='Unnamed: 0')

# %%
popinco=popinc.set_index('Category')

# %%
popinco.to_csv('Number of Accidents with Population and Income data.csv')

# %%
plt.scatter(popinco['Neighborhood Mean Income'],popinco['Number of Accidents'],marker='o',facecolors="green",edgecolors="brown")
plt.xlabel('Neighborhood Mean Income($)')
plt.ylabel('Number of Accidents')
plt.title('Accidents vs Neighborhood Income')
plt.savefig('Accidents vs Neighborhood Income')
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
plt.scatter(popinco['Population'],popinco['Number of Accidents'],marker='o',facecolors="green",edgecolors="brown")
plt.xlabel('Population')
plt.ylabel('Number of Accidents')
plt.title('Accidents vs Neighborhood Population')
plt.savefig('Accidents vs Neighborhood Population_')

# %%
filepath_TPS = "Fatal_Collisions.csv"
TPS_df = pd.read_csv(filepath_TPS)
a=TPS_df[TPS_df['IMPACTYPE']=='Pedestrian Collisions']
a
